# %%
from __future__ import annotations

import datetime
from importlib import reload
from pathlib import Path
from typing import (
    TypeVar,
)

import rich
from mysoc_validator import Transcript

from parl_motion_detector import agreements
from parl_motion_detector.downloader import get_latest_for_date

T = TypeVar("T")

debates_path = Path("..", "data")
tests_path = Path("..", "data", "tests")

# %%
reload(agreements)

debate_date = "2019-06-24"
transcript_path = get_latest_for_date(
    datetime.date.fromisoformat(debate_date), download_path=debates_path
)
transcript = Transcript.from_xml_path(transcript_path)

found_agreements = agreements.get_agreements(transcript, debate_date)
found_divisions = agreements.get_divisions(transcript, debate_date)
# motions.dump_test_data(tests_path)
rich.print(found_agreements)
# Out:
# Collection[Agreement](
#     motions=[
#         Agreement(
#             date='2019-06-24',
#             speech_id='uk.org.publicwhip/debate/2019-06-24b.504.4',
#             major_heading_id='uk.org.publicwhip/debate/2019-06-24b.493.0',
#             minor_heading_id='',
#             paragraph_pid='b504.4/3',
#             end_reason='one line agreement',
#             agreement_pid='',
#             agreed_text='Question put and agreed to.',
#             preceeding_text='I thank the whole House for dealing so swiftly with this
# important matter after the many months that the hon. Member for Richmond Park (Zac Goldsmith)
# spent trying to get the Bill through the House.'
#         ),
#         Agreement(
#             date='2019-06-24',
#             speech_id='uk.org.publicwhip/debate/2019-06-24b.504.6',
#             major_heading_id='uk.org.publicwhip/debate/2019-06-24b.504.5',
#             minor_heading_id='',
#             paragraph_pid='b504.6/11',
#             end_reason='one line agreement',
#             agreement_pid='',
#             agreed_text='Question agreed to.',
#             preceeding_text='(5) Any other proceedings on the Bill may be
# programmed.—(Rebecca Harris.)'
#         ),
#         Agreement(
#             date='2019-06-24',
#             speech_id='uk.org.publicwhip/debate/2019-06-24b.530.1',
#             major_heading_id='uk.org.publicwhip/debate/2019-06-24b.506.0',
#             minor_heading_id='',
#             paragraph_pid='b530.1/2',
#             end_reason='one line agreement',
#             agreement_pid='',
#             agreed_text='Question put and agreed to.',
#             preceeding_text='The format of this debate prevents me from responding to many of
# the points made, so I commit to write formally to every Member who has raised matters that
# require a Government response. I will also seek Government time from the Leader of the House
# for a debate on this important issue as we work towards hosting COP 26. I thank all Members
# for their contributions. This debate is an historic moment and will ensure that we can
# progress the legislation for achieving net zero by 2050 to the other place.'
#         ),
#         Agreement(
#             date='2019-06-24',
#             speech_id='uk.org.publicwhip/debate/2019-06-24b.530.6',
#             major_heading_id='uk.org.publicwhip/debate/2019-06-24b.530.5',
#             minor_heading_id='',
#             paragraph_pid='b530.6/5',
#             end_reason='one line agreement',
#             agreement_pid='',
#             agreed_text='Question agreed to.',
#             preceeding_text='(2) That a further day not later than 5 August be allotted for
# the consideration of the following Estimates for financial year 2019–20: Department for
# International Development, and Department for Education.—(Matt Warman.)'
#         ),
#         Agreement(
#             date='2019-06-24',
#             speech_id='uk.org.publicwhip/debate/2019-06-24b.543.1',
#             major_heading_id='uk.org.publicwhip/debate/2019-06-24b.534.0',
#             minor_heading_id='',
#             paragraph_pid='b543.1/10',
#             end_reason='one line agreement',
#             agreement_pid='',
#             agreed_text='Question put and agreed to.',
#             preceeding_text='I am delighted that the hon. Lady secured this debate. It has
# highlighted some of the challenges that will lead to huge opportunities if we make that
# commitment to spending 2.4% on research and development. We can reach out to the whole
# country. Rather than research being focused in certain cities, we will be able to make sure
# that everyone in this country can share the proceeds of growth from research and development.
# We are looking at smart cities, but every town can be a smart town and every village a smart
# village.'
#         )
#     ]
# )
