# %%
from __future__ import annotations

import datetime
from importlib import reload
from pathlib import Path
from typing import (
    TypeVar,
)

import rich
from mysoc_validator import Transcript

from parl_motion_detector import agreements, mapper, motions
from parl_motion_detector.downloader import get_latest_for_date

T = TypeVar("T")

data_dir = Path("..", "data")

tests_path = Path("..", "data", "tests", "mapper")

# %%
reload(motions)
reload(agreements)
reload(mapper)

"""
- Standard opposition day motion with amendment - 2023-06-27 - tick
- Passing of net zero target (agreement on SI) - 2019-06-24 - tick
- Gaze ceasefire votes (amended motion, two agreements in a row, motion to sit in silence) - 2024-02-21 - tick
- Day with lots of divisions on amendments to be connected (and random other votes) - 2024-04-24 - done
- Fracking Opposition Day Amendment - timetable change - complicated motion.  - 2022-10-19 - done
- Vote on government agenda - 2024-07-23 - done
- disagreeing with lords amendments - 2024-04-22
"""

year = 2024
current_date = datetime.datetime.now().date()
chamber = Transcript.Chamber.COMMONS
# all dates in year to date
dates_in_year = [
    datetime.date(year, 1, 1) + datetime.timedelta(days=i) for i in range(365)
]
# all dates in year to dat
dates_in_year = [x.isoformat() for x in dates_in_year if x <= current_date]

# dates_in_year = ["2023-10-25"]

for debate_date in dates_in_year:
    try:
        transcript_path = get_latest_for_date(
            datetime.date.fromisoformat(debate_date), download_path=data_dir
        )
    except FileNotFoundError:
        continue
    # fix 2019 error
    txt = transcript_path.read_text()
    if "21&#10;14" in txt:
        txt = txt.replace("21&#10;14", "2114")
        transcript_path.write_text(txt)
    transcript = Transcript.from_xml_path(transcript_path)

    mm = mapper.MotionMapper(
        transcript, debate_date=debate_date, data_dir=data_dir, chamber=chamber
    )

    mm.assign()
    results = mm.export()
    results.to_data_dir(data_dir / "interim" / "results")
# Out:
# 2024-01-01
# 2024-01-02
# 2024-01-03
# 2024-01-04
# 2024-01-05
# 2024-01-06
# 2024-01-07
# 2024-01-08
# 2024-01-09
# 2024-01-10
# 2024-01-11
# 2024-01-12
# 2024-01-13
# 2024-01-14
# 2024-01-15
# 2024-01-16
# 2024-01-17
# 2024-01-18
# 2024-01-19
# 2024-01-20
# 2024-01-21
# 2024-01-22
# 2024-01-23
# 2024-01-24
# 2024-01-25
# 2024-01-26
# 2024-01-27
# 2024-01-28
# 2024-01-29
# 2024-01-30
# 2024-01-31
# 2024-02-01
# 2024-02-02
# 2024-02-03
# 2024-02-04
# 2024-02-05
# 2024-02-06
# 2024-02-07
# 2024-02-08
# 2024-02-09
# 2024-02-10
# 2024-02-11
# 2024-02-12
# 2024-02-13
# 2024-02-14
# 2024-02-15
# 2024-02-16
# 2024-02-17
# 2024-02-18
# 2024-02-19
# 2024-02-20
# 2024-02-21
# 2024-02-22
# 2024-02-23
# 2024-02-24
# 2024-02-25
# 2024-02-26
# 2024-02-27
# 2024-02-28
# 2024-02-29
# 2024-03-01
# 2024-03-02
# 2024-03-03
# 2024-03-04
# 2024-03-05
# 2024-03-06
# 2024-03-07
# 2024-03-08
# 2024-03-09
# 2024-03-10
# 2024-03-11
# 2024-03-12
# 2024-03-13
# 2024-03-14
# 2024-03-15
# 2024-03-16
# 2024-03-17
# 2024-03-18
# 2024-03-19
# 2024-03-20
# 2024-03-21
# 2024-03-22
# 2024-03-23
# 2024-03-24
# 2024-03-25
# 2024-03-26
# 2024-03-27
# 2024-03-28
# 2024-03-29
# 2024-03-30
# 2024-03-31
# 2024-04-01
# 2024-04-02
# 2024-04-03
# 2024-04-04
# 2024-04-05
# 2024-04-06
# 2024-04-07
# 2024-04-08
# 2024-04-09
# 2024-04-10
# 2024-04-11
# 2024-04-12
# 2024-04-13
# 2024-04-14
# 2024-04-15
# 2024-04-16
# 2024-04-17
# 2024-04-18
# 2024-04-19
# 2024-04-20
# 2024-04-21
# 2024-04-22
# 2024-04-23
# 2024-04-24
# 2024-04-25
# 2024-04-26
# 2024-04-27
# 2024-04-28
# 2024-04-29
# 2024-04-30
# 2024-05-01
# 2024-05-02
# 2024-05-03
# 2024-05-04
# 2024-05-05
# 2024-05-06
# 2024-05-07
# 2024-05-08
# 2024-05-09
# 2024-05-10
# 2024-05-11
# 2024-05-12
# 2024-05-13
# 2024-05-14
# 2024-05-15
# 2024-05-16
# 2024-05-17
# 2024-05-18
# 2024-05-19
# 2024-05-20
# 2024-05-21
# 2024-05-22
# 2024-05-23
# 2024-05-24
# 2024-05-25
# 2024-05-26
# 2024-05-27
# 2024-05-28
# 2024-05-29
# 2024-05-30
# 2024-05-31
# 2024-06-01
# 2024-06-02
# 2024-06-03
# 2024-06-04
# 2024-06-05
# 2024-06-06
# 2024-06-07
# 2024-06-08
# 2024-06-09
# 2024-06-10
# 2024-06-11
# 2024-06-12
# 2024-06-13
# 2024-06-14
# 2024-06-15
# 2024-06-16
# 2024-06-17
# 2024-06-18
# 2024-06-19
# 2024-06-20
# 2024-06-21
# 2024-06-22
# 2024-06-23
# 2024-06-24
# 2024-06-25
# 2024-06-26
# 2024-06-27
# 2024-06-28
# 2024-06-29
# 2024-06-30
# 2024-07-01
# 2024-07-02
# 2024-07-03
# 2024-07-04
# 2024-07-05
# 2024-07-06
# 2024-07-07
# 2024-07-08
# 2024-07-09
# 2024-07-10
# 2024-07-11
# 2024-07-12
# 2024-07-13
# 2024-07-14
# 2024-07-15
# 2024-07-16
# 2024-07-17
# 2024-07-18
# 2024-07-19
# 2024-07-20
# 2024-07-21
# 2024-07-22
# 2024-07-23
# 2024-07-24
# 2024-07-25
# 2024-07-26
# 2024-07-27
# 2024-07-28
# 2024-07-29
# 2024-07-30
# 2024-07-31
# 2024-08-01
# 2024-08-02
# 2024-08-03
# 2024-08-04
# 2024-08-05
# 2024-08-06
# 2024-08-07
# 2024-08-08
# 2024-08-09
# 2024-08-10
# 2024-08-11
# 2024-08-12
# 2024-08-13
# 2024-08-14
# 2024-08-15
# 2024-08-16
# 2024-08-17
# 2024-08-18
# 2024-08-19
# 2024-08-20
# 2024-08-21
# 2024-08-22
# 2024-08-23
# 2024-08-24
# 2024-08-25
# 2024-08-26
# 2024-08-27
# 2024-08-28
# 2024-08-29
# 2024-08-30
# 2024-08-31
# 2024-09-01
# 2024-09-02
# 2024-09-03
# 2024-09-04
# 2024-09-05
# 2024-09-06
# 2024-09-07
# 2024-09-08
# 2024-09-09
# 2024-09-10
# 2024-09-11
# 2024-09-12
# 2024-09-13
# 2024-09-14
# 2024-09-15
# 2024-09-16
# 2024-09-17
# 2024-09-18
# 2024-09-19
# 2024-09-20
# 2024-09-21
# 2024-09-22
# 2024-09-23
# 2024-09-24
# 2024-09-25
# 2024-09-26
# 2024-09-27
# 2024-09-28
# 2024-09-29
# 2024-09-30
# 2024-10-01
# 2024-10-02
# 2024-10-03
# 2024-10-04
# 2024-10-05
# 2024-10-06
# 2024-10-07
# 2024-10-08
# 2024-10-09
# 2024-10-10
# 2024-10-11
# 2024-10-12
# 2024-10-13
# 2024-10-14
# Agreement uk.org.publicwhip/debate/2024-10-14c.673.0.12 not assigned - no relevant motions.
# 2024-10-15
# 2024-10-16
# 2024-10-17
# 2024-10-18
# 2024-10-19
# 2024-10-20
# 2024-10-21
# 2024-10-22
# 2024-10-23
# 2024-10-24
# 2024-10-25
# 2024-10-26
# 2024-10-27
# 2024-10-28
# 2024-10-29
# 2024-10-30
# 2024-10-31
# 2024-11-01
# 2024-11-02
# 2024-11-03
# 2024-11-04
# 2024-11-05
# 2024-11-06
# 2024-11-07
# 2024-11-08
# 2024-11-09
# 2024-11-10
# 2024-11-11
# 2024-11-12

# %%
rh = mapper.ResultsHolder.from_data_dir_composite(
    data_dir / "interim" / "results", date="2024", chamber=Transcript.Chamber.COMMONS
)

rh.export(data_dir / "processed" / "parquet")

# %%
results = mm.export()
rich.print(results)
results.to_data_dir(data_dir / "interim" / "results")
# Out:
# ResultsHolder(
#     date='2024-01-08',
#     chamber=<Chamber.COMMONS: 'house-of-commons'>,
#     division_motions=[],
#     agreement_motions=[
#         Agreement(
#             date='2024-01-08',
#             speech_id='uk.org.publicwhip/debate/2024-01-08d.132.1',
#             major_heading_id='uk.org.publicwhip/debate/2024-01-08d.120.0',
#             minor_heading_id='',
#             paragraph_pid='d132.1/3',
#             end_reason='one_line_agreement',
#             agreement_pid='',
#             agreed_text='Question put and agreed to.',
#             preceeding_text='I have campaigned on Gilsland for only 14 years; in
# Herefordshire, there is Pontrilas and there are other stations—whether they were killed by Dr
# Beeching or others down the years—that are sought as an opportunity for a reopening of our
# railway infrastructure. As we have seen with the Waverley line in Scotland, there is a
# definite desire for such railways to be reinvigorated and for new stations to return. Without
# a shadow of a doubt, I will personally take the issue up with the trains Minister.',
#             after_text='House adjourned.',
#             motion=Motion(
#                 date='2024-01-08',
#                 motion_title='Adjournment Debate: Rural Transport',
#                 major_heading_id='uk.org.publicwhip/debate/2024-01-08d.120.0',
#                 minor_heading_id='',
#                 major_heading_title='Rural Transport',
#                 minor_heading_title='None',
#                 speech_start_pid='d120.1/1',
#                 speech_id='uk.org.publicwhip/debate/2024-01-08d.120.1',
#                 final_speech_id='uk.org.publicwhip/debate/2024-01-08d.120.1',
#                 end_reason='one line motion',
#                 motion_lines=[
#                     'Motion made, and Question proposed, That this House do now
# adjourn.—(Suzanne Webb.)'
#                 ],
#                 flags=['one_line_motion'],
#                 gid='uk.org.publicwhip/debate/2024-01-08d.120.1.1'
#             ),
#             motion_assignment_reason='single motion and decision',
#             gid='uk.org.publicwhip/debate/2024-01-08d.132.1.3'
#         )
#     ]
# )

# %%
for agreement in mm.found_agreements:
    if agreement.major_heading_id == "uk.org.publicwhip/debate/2023-03-06d.72.0":
        rich.print(agreement)

# %%
rich.print(mm.found_motions)
# Out:
# MotionCollection(
#     motions=[
#         Motion(
#             date='2020-10-21',
#             motion_title='Leave for Bill: Vehicle Registration Offences (Penalty Points)',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1079.0',
#             minor_heading_id='',
#             major_heading_title='Vehicle Registration Offences (Penalty Points)',
#             minor_heading_title='None',
#             speech_start_pid='e1079.2/1',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1079.2',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1079.2',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'I beg to move,',
#                 'That leave be given to bring in a Bill to make vehicle registration offences
# under the Vehicle Excise and Registration Act 1994 attract driving record penalty points; and
# for connected purposes.'
#             ],
#             flags=['main_question'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1079.2.1'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Vehicle Registration Offences (Penalty Points)',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1079.0',
#             minor_heading_id='',
#             major_heading_title='Vehicle Registration Offences (Penalty Points)',
#             minor_heading_title='None',
#             speech_start_pid='e1079.2/12',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1079.2',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1079.2',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'Ordered,',
#                 'That Andrew Griffith, Mr Andrew Mitchell, Bob Blackman, Caroline Nokes,
# Damian Green, Damian Hinds, Mrs Flick Drummond, Henry Smith, James Sunderland, Sir Mike
# Penning, Sir Peter Bottomley, and Tim Loughton present the Bill.'
#             ],
#             flags=['after_decision'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1079.2.12'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Additional Covid-19 Restrictions: Fair Economic Support',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1081.1',
#             minor_heading_id='',
#             major_heading_title='Additional Covid-19 Restrictions: Fair Economic Support',
#             minor_heading_title='None',
#             speech_start_pid='e1081.3/1',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1081.3',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1081.3',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'I beg to move,',
#                 'That this House calls on the Government to publish clear and fair national
# criteria for financial support for jobs and businesses in areas facing additional
# restrictions, to be voted on in Parliament; and calls on the Government to make good on its
# claim that workers faced with hardship who are subject to the Job Support Scheme extension
# will receive at least 80 percent of their previous incomes.'
#             ],
#             flags=['main_question'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1081.3.1'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Additional Covid-19 Restrictions: Fair Economic Support',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1081.1',
#             minor_heading_id='',
#             major_heading_title='Additional Covid-19 Restrictions: Fair Economic Support',
#             minor_heading_title='None',
#             speech_start_pid='e1086.3/1',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1086.3',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1086.3',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'I beg to move a manuscript amendment, to leave out from “House” to the end
# of the Question and add:',
#                 '“recognises the virus is spreading differently across the country which
# supports the need for a regional and local approach; acknowledges the fact that repeated
# national lockdowns should be avoided given the cost they have on mental wellbeing, access to
# NHS treatment, and jobs in the economy; supports the Government’s Job Support Scheme which
# protects the jobs and incomes of those in affected businesses; recognises the extra financial
# support provided to Local Authorities for enforcement, local contact tracing and businesses,
# and approves of Government trying to work with local representatives to improve enforcement
# and Test and Trace.”.'
#             ],
#             flags=['main_question'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1086.3.1'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Additional Covid-19 Restrictions: Fair Economic Support',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1081.1',
#             minor_heading_id='',
#             major_heading_title='Additional Covid-19 Restrictions: Fair Economic Support',
#             minor_heading_title='None',
#             speech_start_pid='e1123.1/9',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1123.1',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1123.1',
#             end_reason='one line motion',
#             motion_lines=[
#                 'Question put (Standing Order No. 31(2)), That the original words stand part
# of the Question.'
#             ],
#             flags=['one_line_motion', 'abstract_motion'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1123.1.9'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Additional Covid-19 Restrictions: Fair Economic Support',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1081.1',
#             minor_heading_id='',
#             major_heading_title='Additional Covid-19 Restrictions: Fair Economic Support',
#             minor_heading_title='None',
#             speech_start_pid='e1124.1/4',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1124.1',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1124.1',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'Question put forthwith (Standing Order No. 31(2)), That the proposed words
# be there added.',
#                 'Question agreed to.'
#             ],
#             flags=['abstract_motion'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1124.1.4'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Additional Covid-19 Restrictions: Fair Economic Support',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1081.1',
#             minor_heading_id='',
#             major_heading_title='Additional Covid-19 Restrictions: Fair Economic Support',
#             minor_heading_title='None',
#             speech_start_pid='e1124.1/7',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1124.1',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1124.1',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'Resolved,',
#                 'That this House recognises the virus is sa1preading differently across the
# country which supports the need for a regional and local approach; acknowledges the fact that
# repeated national lockdowns should be avoided given the cost they have on mental wellbeing,
# access to NHS treatment, and jobs in the economy; supports the Government’s Job Support
# Scheme which protects the jobs and incomes of those in affected businesses; recognises the
# extra financial support provided to Local Authorities for enforcement, local contact tracing
# and businesses, and approves of Government trying to work with local representatives to
# improve enforcement and Test and Trace.'
#             ],
#             flags=['after_decision'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1124.1.7'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Free School Meals',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1130.0',
#             minor_heading_id='',
#             major_heading_title='Free School Meals',
#             minor_heading_title='None',
#             speech_start_pid='e1130.2/1',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1130.2',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1130.2',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'I beg to move,',
#                 'That this House calls on the Government to continue directly funding
# provision of free school meals over the school holidays until Easter 2021 to prevent over a
# million children going hungry during this crisis.'
#             ],
#             flags=['main_question'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1130.2.1'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Amendment: Free School Meals',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1130.0',
#             minor_heading_id='',
#             major_heading_title='Free School Meals',
#             minor_heading_title='None',
#             speech_start_pid='e1133.0/1',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1133.0',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1133.0',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'I beg to move an amendment, to leave out from “House” to the end of the
# Question and add:',
#                 '“notes that schools are now fully operational following the covid-19
# outbreak, and will continue to offer free school meals in term time; welcomes the substantial
# support provided by the Government to children worth £550 million annually; further welcomes
# that this support has been bolstered by almost £53 billion worth of income protection
# schemes, and £9.3 billion of additional welfare payments; notes that eligible families have
# also been supported throughout lockdown through the receipt of meal vouchers worth £380
# million while schools were partially closed, alongside the Holiday Activities and Food Fund;
# and further supports the Government in its ongoing activities to help the most vulnerable
# children in society.”'
#             ],
#             flags=['motion_amendment'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1133.0.1'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Free School Meals',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1130.0',
#             minor_heading_id='',
#             major_heading_title='Free School Meals',
#             minor_heading_title='None',
#             speech_start_pid='e1170.1/7',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1170.1',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1170.1',
#             end_reason='one line motion',
#             motion_lines=[
#                 'Question put (Standing Order No. 31(2)), That the original words stand part
# of the Question.'
#             ],
#             flags=['one_line_motion', 'abstract_motion'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1170.1.7'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Free School Meals',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1130.0',
#             minor_heading_id='',
#             major_heading_title='Free School Meals',
#             minor_heading_title='None',
#             speech_start_pid='e1172.1/4',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1172.1',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1172.1',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'Question put forthwith (Standing Order No. 31(2)), That the proposed words
# be there added.',
#                 'Question agreed to.'
#             ],
#             flags=['abstract_motion'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1172.1.4'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Free School Meals',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1130.0',
#             minor_heading_id='',
#             major_heading_title='Free School Meals',
#             minor_heading_title='None',
#             speech_start_pid='e1172.1/7',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1172.1',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1172.1',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'Resolved,',
#                 'That this House notes that schools are now fully operational following the
# covid-19 outbreak, and will continue to offer free school meals in term time; welcomes the
# substantial support provided by the Government to children worth £550 million annually;
# further welcomes that this support has been bolstered by almost £53 billion worth of income
# protection schemes, and £9.3 billion of additional welfare payments; notes that eligible
# families have also been supported throughout lockdown through the receipt of meal vouchers
# worth £380 million while schools were partially closed, alongside the Holiday Activities and
# Food Fund; and further supports the Government in its ongoing activities to help the most
# vulnerable children in society.'
#             ],
#             flags=['after_decision'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1172.1.7'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Delegated Legislation',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1177.1',
#             minor_heading_id='',
#             major_heading_title='Delegated Legislation',
#             minor_heading_title='None',
#             speech_start_pid='e1177.2/2',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1177.2',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1177.4',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'Motion made, and Question put forthwith (Standing Order No. 118(6)),',
#                 'That the draft Communications Act (e-Commerce) (EU Exit) Regulations 2020,
# which were laid before this House on 24 September, be approved.'
#             ],
#             flags=[],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1177.2.2'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Delegated Legislation: Education',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1177.1',
#             minor_heading_id='uk.org.publicwhip/debate/2020-10-21e.1177.5',
#             major_heading_title='Delegated Legislation',
#             minor_heading_title='Education',
#             speech_start_pid='e1177.6/1',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1177.6',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1177.6',
#             end_reason='one line motion',
#             motion_lines=[
#                 'That the draft Higher Education (Fee Limits and Student Support) (England)
# (Coronavirus) (Revocation) Regulations 2020, which were laid before this House on 28
# September, be approved.—(David Duguid.)'
#             ],
#             flags=['one_line_motion'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1177.6.1'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Adjournment Debate: Hedge End Train Station: Accessibility',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1180.0',
#             minor_heading_id='',
#             major_heading_title='Hedge End Train Station: Accessibility',
#             minor_heading_title='None',
#             speech_start_pid='e1180.1/1',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1180.1',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1180.1',
#             end_reason='one line motion',
#             motion_lines=[
#                 'Motion made, and Question proposed, That this House do now adjourn.—(David
# Duguid.)'
#             ],
#             flags=['one_line_motion'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1180.1.1'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Deferred Divisions: Exiting the European Union (Immigration)',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1193.0',
#             minor_heading_id='uk.org.publicwhip/debate/2020-10-21e.1193.1',
#             major_heading_title='Deferred Divisions',
#             minor_heading_title='Exiting the European Union (Immigration)',
#             speech_start_pid='e1193.2/1',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1193.2',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1193.2',
#             end_reason='one line motion',
#             motion_lines=[
#                 "That the draft Citizens' Rights (Application Deadline and Temporary
# Protection) (EU Exit) Regulations 2020, which were laid before this House on 21 September, be
# approved."
#             ],
#             flags=['one_line_motion'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1193.2.1'
#         ),
#         Motion(
#             date='2020-10-21',
#             motion_title='Deferred Divisions: Community Infrastructure Levy',
#             major_heading_id='uk.org.publicwhip/debate/2020-10-21e.1193.0',
#             minor_heading_id='uk.org.publicwhip/debate/2020-10-21e.1205.0',
#             major_heading_title='Deferred Divisions',
#             minor_heading_title='Community Infrastructure Levy',
#             speech_start_pid='e1205.1/1',
#             speech_id='uk.org.publicwhip/debate/2020-10-21e.1205.1',
#             final_speech_id='uk.org.publicwhip/debate/2020-10-21e.1205.1',
#             end_reason='one line motion',
#             motion_lines=[
#                 'That the draft Community Infrastructure Levy (Amendment) (England) (No. 2)
# Regulations 2020, which were laid before this House on 28 September, be approved.'
#             ],
#             flags=['one_line_motion'],
#             gid='uk.org.publicwhip/debate/2020-10-21e.1205.1.1'
#         )
#     ]
# )
