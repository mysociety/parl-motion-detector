# %%
from __future__ import annotations

import datetime
from importlib import reload
from pathlib import Path
from typing import (
    TypeVar,
)

import rich
from mysoc_validator import Transcript

from parl_motion_detector import agreements, mapper, motions
from parl_motion_detector.downloader import get_latest_for_date

T = TypeVar("T")

debates_path = Path("..", "data")
tests_path = Path("..", "data", "tests", "mapper")

# %%
reload(motions)
reload(agreements)
reload(mapper)

"""
- Standard opposition day motion with amendment - 2023-06-27 - tick
- Passing of net zero target (agreement on SI) - 2019-06-24 - tick
- Gaze ceasefire votes (amended motion, two agreements in a row, motion to sit in silence) - 2024-02-21 - tick
- Day with lots of divisions on amendments to be connected (and random other votes) - 2024-04-24 - done
- Fracking Opposition Day Amendment - timetable change - complicated motion.  - 2022-10-19 - done
- Vote on government agenda - 2024-07-23 - done
- disagreeing with lords amendments - 2024-04-22
"""

year = 2024
current_date = datetime.date(year, 11, 6)
# all dates in year to date
dates_in_year = [
    datetime.date(year, 1, 1) + datetime.timedelta(days=i) for i in range(365)
]
# all dates in year to dat
dates_in_year = [x.isoformat() for x in dates_in_year if x <= current_date]

dates_in_year = ["2024-03-12"]


for debate_date in dates_in_year:
    print(debate_date)
    try:
        transcript_path = get_latest_for_date(
            datetime.date.fromisoformat(debate_date), download_path=debates_path
        )
    except FileNotFoundError:
        continue
    transcript = Transcript.from_xml_path(transcript_path)

    mm = mapper.MotionMapper(transcript, debate_date)

    mm.assign()
# Out:
# 2024-01-01
# 2024-01-02
# 2024-01-03
# 2024-01-04
# 2024-01-05
# 2024-01-06
# 2024-01-07
# 2024-01-08
# 2024-01-09
# 2024-01-10
# 2024-01-11
# 2024-01-12
# 2024-01-13
# 2024-01-14
# 2024-01-15
# 2024-01-16
# 2024-01-17
# 2024-01-18
# 2024-01-19
# 2024-01-20
# 2024-01-21
# 2024-01-22
# 2024-01-23
# 2024-01-24
# 2024-01-25
# 2024-01-26
# 2024-01-27
# 2024-01-28
# 2024-01-29
# 2024-01-30
# 2024-01-31
# 2024-02-01
# 2024-02-02
# 2024-02-03
# 2024-02-04
# 2024-02-05
# 2024-02-06
# 2024-02-07
# 2024-02-08
# 2024-02-09
# 2024-02-10
# 2024-02-11
# 2024-02-12
# 2024-02-13
# 2024-02-14
# 2024-02-15
# 2024-02-16
# 2024-02-17
# 2024-02-18
# 2024-02-19
# 2024-02-20
# 2024-02-21
# 2024-02-22
# 2024-02-23
# 2024-02-24
# 2024-02-25
# 2024-02-26
# 2024-02-27
# 2024-02-28
# 2024-02-29
# 2024-03-01
# 2024-03-02
# 2024-03-03
# 2024-03-04
# 2024-03-05
# 2024-03-06
# 2024-03-07
# 2024-03-08
# 2024-03-09
# 2024-03-10
# 2024-03-11
# 2024-03-12
# DivisionHolder(
#     date='2024-03-12',
#     speech_id='uk.org.publicwhip/debate/2024-03-12b.257.2',
#     major_heading_id='uk.org.publicwhip/debate/2024-03-12b.169.2',
#     minor_heading_id='',
#     minor_heading_text='',
#     paragraph_pid='',
#     preceding_speech='Question put.',
#     after_speech='tag=\'speech\' id=\'uk.org.publicwhip/debate/2024-03-12b.257.3\' type=\'\'
# nospeaker=\'true\' speakername=None speech_type=None person_id=None colnum=\'257\'
# time=\'18:38:00\' url=\'\' oral_qnum=None items=[SpeechItem(tag=\'p\', pid=\'b257.3/1\',
# qnum=None, class_=None, pwmotiontext=None, content=MixedContentHolder(text=\'The House
# divided: Ayes 318, Noes 43.\', raw=\'The House divided: Ayes 318, Noes 43.\')),
# SpeechItem(tag=\'p\', pid=\'b257.3/2\', qnum=None, class_=None, pwmotiontext=None,
# content=MixedContentHolder(text=\'Question accordingly agreed to.\', raw=\'Question
# accordingly agreed to.\')), SpeechItem(tag=\'p\', pid=\'b257.3/3\', qnum=None, class_=None,
# pwmotiontext=None, content=MixedContentHolder(text=\'Resolved,\', raw=\'Resolved,\')),
# SpeechItem(tag=\'p\', pid=\'b257.3/4\', qnum=None, class_=\'indent\', pwmotiontext=\'yes\',
# content=MixedContentHolder(text=\'That income tax is charged for the tax year 2024-25.\',
# raw=\'That income tax is charged for the tax year 2024-25.\')), SpeechItem(tag=\'p\',
# pid=\'b257.3/5\', qnum=None, class_=\'indent\', pwmotiontext=\'yes\',
# content=MixedContentHolder(text=\'And it is declared that it is expedient in the public
# interest that this Resolution should have statutory effect under the provisions of the
# Provisional Collection of Taxes Act 1968.\', raw=\'And it is declared that it is expedient in
# the public interest that this Resolution should have statutory effect under the provisions of
# the Provisional Collection of Taxes Act 1968.\')), SpeechItem(tag=\'p\', pid=\'b257.3/6\',
# qnum=None, class_=None, pwmotiontext=None, content=MixedContentHolder(text=\'The Deputy
# Speaker put forthwith the Questions necessary to dispose of the motions made in the name of
# the Chancellor of the Exchequer (Standing Order No. 51(3)).\', raw=\'The Deputy Speaker put
# forthwith the Questions necessary to dispose of the motions made in the name of the
# Chancellor of the Exchequer (<phrase class="standing-order" code="51(3)">Standing Order No.
# 51(3)</phrase>).\'))]',
#     gid='uk.org.publicwhip/debate/2024-03-12b.257.2'
# )
# [
#     Motion(
#         date='2024-03-12',
#         motion_title='Income Tax (Charge)',
#         major_heading_id='uk.org.publicwhip/debate/2024-03-12b.169.2',
#         minor_heading_id='',
#         major_heading_title='Income Tax (Charge)',
#         minor_heading_title='None',
#         speech_start_pid='b169.3/2',
#         speech_id='uk.org.publicwhip/debate/2024-03-12b.169.3',
#         final_speech_id='',
#         end_reason='Valid end character',
#         motion_lines=[
#             'Question again proposed,',
#             'That income tax is charged for the tax year 2024-25.'
#         ],
#         flags=[],
#         gid='uk.org.publicwhip/debate/2024-03-12b.169.3.2'
#     ),
#     Motion(
#         date='2024-03-12',
#         motion_title='Income Tax (Charge)',
#         major_heading_id='uk.org.publicwhip/debate/2024-03-12b.169.2',
#         minor_heading_id='',
#         major_heading_title='Income Tax (Charge)',
#         minor_heading_title='None',
#         speech_start_pid='b257.3/3',
#         speech_id='uk.org.publicwhip/debate/2024-03-12b.257.3',
#         final_speech_id='',
#         end_reason='Valid end character',
#         motion_lines=['Resolved,', 'That income tax is charged for the tax year 2024-25.'],
#         flags=['after_decision'],
#         gid='uk.org.publicwhip/debate/2024-03-12b.257.3.3'
#     ),
#     Motion(
#         date='2024-03-12',
#         motion_title='Income Tax (Charge): 2. Income tax (main rates)',
#         major_heading_id='uk.org.publicwhip/debate/2024-03-12b.169.2',
#         minor_heading_id='uk.org.publicwhip/debate/2024-03-12b.260.0',
#         major_heading_title='Income Tax (Charge)',
#         minor_heading_title='2. Income tax (main rates)',
#         speech_start_pid='b260.1/1',
#         speech_id='uk.org.publicwhip/debate/2024-03-12b.260.1',
#         final_speech_id='',
#         end_reason='next is not subitem, ends in non alphanumeric, not inserted; current does
# not end  continuation character',
#         motion_lines=[
#             'Resolved,',
#             'That for the tax year 2024-25 the main rates of income tax are as follows—',
#             '(a) the basic rate is 20%,',
#             '(b) the higher rate is 40%, and',
#             '(c) the additional rate is 45%.'
#         ],
#         flags=['after_decision', 'complex_motion'],
#         gid='uk.org.publicwhip/debate/2024-03-12b.260.1.1'
#     ),
#     Motion(
#         date='2024-03-12',
#         motion_title='Income Tax (Charge): 3. Income tax  (default and savings rates)',
#         major_heading_id='uk.org.publicwhip/debate/2024-03-12b.169.2',
#         minor_heading_id='uk.org.publicwhip/debate/2024-03-12b.260.2',
#         major_heading_title='Income Tax (Charge)',
#         minor_heading_title='3. Income tax  (default and savings rates)',
#         speech_start_pid='b260.3/1',
#         speech_id='uk.org.publicwhip/debate/2024-03-12b.260.3',
#         final_speech_id='',
#         end_reason='next is not subitem, ends in non alphanumeric, not inserted; current does
# not end  continuation character',
#         motion_lines=[
#             'Resolved,',
#             'That—',
#             '(1) For the tax year 2024-25 the default rates of income tax are as follows—',
#             '(a) the default basic rate is 20%,',
#             '(b) the default higher rate is 40%, and',
#             '(c) the default additional rate is 45%.',
#             '(2) For the tax year 2024-25 the savings rates of income tax are as follows—',
#             '(a) the savings basic rate is 20%,',
#             '(b) the savings higher rate is 40%, and',
#             '(c) the savings additional rate is 45%.'
#         ],
#         flags=['after_decision', 'complex_motion'],
#         gid='uk.org.publicwhip/debate/2024-03-12b.260.3.1'
#     ),
#     Motion(
#         date='2024-03-12',
#         motion_title='Income Tax (Charge): 4. Income tax  (starting rate limit for savings)',
#         major_heading_id='uk.org.publicwhip/debate/2024-03-12b.169.2',
#         minor_heading_id='uk.org.publicwhip/debate/2024-03-12b.261.0',
#         major_heading_title='Income Tax (Charge)',
#         minor_heading_title='4. Income tax  (starting rate limit for savings)',
#         speech_start_pid='b261.1/1',
#         speech_id='uk.org.publicwhip/debate/2024-03-12b.261.1',
#         final_speech_id='',
#         end_reason='next is not subitem, ends in non alphanumeric, not inserted; current does
# not end  continuation character',
#         motion_lines=[
#             'Resolved,',
#             'That—',
#             '(1) For the tax year 2024-25 the amount specified in section 12(3) of the Income
# Tax Act 2007 (the starting rate limit for savings) is “£5,000”.',
#             '(2) Accordingly, section 21 of that Act (indexation) does not apply in relation
# to the starting rate limit for savings for that tax year.'
#         ],
#         flags=['after_decision', 'complex_motion'],
#         gid='uk.org.publicwhip/debate/2024-03-12b.261.1.1'
#     )
# ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[192], line 39
#      35 transcript = Transcript.from_xml_path(transcript_path)
#      37 mm = mapper.MotionMapper(transcript, debate_date)
# ---> 39 mm.assign()
#
# File /workspaces/parl_motion_detector/src/parl_motion_detector/mapper.py:461, in MotionMapper.assign(self)
#     459 rich.print(decisions[0])
#     460 rich.print(possible_motions)
# --> 461 raise ValueError("Too many motions found")
#
# ValueError: Too many motions found

# %%
rich.print(mm.export())
# Out:
# {
#     'division_motions': {},
#     'agreement_motions': {
#         'uk.org.publicwhip/debate/2024-02-07c.275.2.27': Motion(
#             date='2024-02-07',
#             motion_title='Leave for Bill: State Pension Age (Compensation)',
#             major_heading_id='uk.org.publicwhip/debate/2024-02-07c.275.0',
#             minor_heading_id='',
#             major_heading_title='State Pension Age (Compensation)',
#             minor_heading_title='None',
#             speech_start_pid='c275.2/1',
#             speech_id='uk.org.publicwhip/debate/2024-02-07c.275.2',
#             final_speech_id='',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'I beg to move,',
#                 'That leave be given to bring in a Bill to require the Secretary of State to
# publish proposals for a compensation scheme for women born between 6th April 1950 and 5th
# April 1960 inclusive who have been affected by increases in the state pension age; and for
# connected purposes.'
#             ],
#             flags=['main_question'],
#             gid='uk.org.publicwhip/debate/2024-02-07c.275.2.1'
#         ),
#         'uk.org.publicwhip/debate/2024-02-07c.292.2.6': Motion(
#             date='2024-02-07',
#             motion_title='Police Grant Report',
#             major_heading_id='uk.org.publicwhip/debate/2024-02-07c.279.0',
#             minor_heading_id='',
#             major_heading_title='Police Grant Report',
#             minor_heading_title='None',
#             speech_start_pid='c292.2/7',
#             speech_id='uk.org.publicwhip/debate/2024-02-07c.292.2',
#             final_speech_id='',
#             end_reason='Valid end character',
#             motion_lines=[
#                 'Resolved,',
#                 'That the Police Grant Report (England and Wales) 2024–25 (HC 482), which was
# laid before this House on 31 January, be approved.'
#             ],
#             flags=['after_decision'],
#             gid='uk.org.publicwhip/debate/2024-02-07c.292.2.7'
#         ),
#         'uk.org.publicwhip/debate/2024-02-07c.328.1.8': Motion(
#             date='2024-02-07',
#             motion_title='',
#             major_heading_id='uk.org.publicwhip/debate/2024-02-07c.294.0',
#             minor_heading_id='',
#             major_heading_title='',
#             minor_heading_title='',
#             speech_start_pid='c328.1/8',
#             speech_id='uk.org.publicwhip/debate/2024-02-07c.328.1',
#             final_speech_id='',
#             end_reason='',
#             motion_lines=[
#                 'I beg to move,\nThat the Local Government Finance Report (England) 2024–25
# (HC 318), which was laid before this House on 5 February, be approved.',
#                 'Resolved,\nThat the Local Government Finance Report (England) 2024–25 (HC
# 318), which was laid before this House on 5 February, be approved.',
#                 'Resolved,\nThat the Referendums Relating to Council Tax Increases
# (Principles) (England) Report 2024–25 (HC 319), which was laid before this House on 5
# February, be approved.—(Simon Hoare.)',
#                 'Resolved,\nThat the Referendums Relating to Council Tax Increases
# (Alternative Notional Amounts) (England) Report 2024–25 (HC 320), which was laid before this
# House on 5 February, be approved.—(Simon Hoare.)'
#             ],
#             flags=[],
#             gid='uk.org.publicwhip/debate/2024-02-07c.328.1.8'
#         ),
#         'uk.org.publicwhip/debate/2024-02-07c.330.10.2': Motion(
#             date='2024-02-07',
#             motion_title='Approve: Water Industry (Special Administration) Regulations 2024',
#             major_heading_id='uk.org.publicwhip/debate/2024-02-07c.330.7',
#             minor_heading_id='uk.org.publicwhip/debate/2024-02-07c.330.9',
#             major_heading_title='Delegated Legislation',
#             minor_heading_title='Gender recognition',
#             speech_start_pid='c330.10/3',
#             speech_id='uk.org.publicwhip/debate/2024-02-07c.330.10',
#             final_speech_id='',
#             end_reason='amendment closed with name',
#             motion_lines=[
#                 'Motion made, and Question put forthwith (Standing Order No. 118(6)),',
#                 'That the draft Water Industry (Special Administration) Regulations 2024,
# which were laid before this House on 15 January, be approved. —(Mark Jenkinson.)'
#             ],
#             flags=[],
#             gid='uk.org.publicwhip/debate/2024-02-07c.330.10.3'
#         ),
#         'uk.org.publicwhip/debate/2024-02-07c.330.12.2': Motion(
#             date='2024-02-07',
#             motion_title='Approve: Water Industry Act 1991 (Amendment) Order 2024',
#             major_heading_id='uk.org.publicwhip/debate/2024-02-07c.330.7',
#             minor_heading_id='uk.org.publicwhip/debate/2024-02-07c.330.11',
#             major_heading_title='Delegated Legislation',
#             minor_heading_title='Insolvency',
#             speech_start_pid='c330.12/3',
#             speech_id='uk.org.publicwhip/debate/2024-02-07c.330.12',
#             final_speech_id='',
#             end_reason='amendment closed with name',
#             motion_lines=[
#                 'Motion made, and Question put forthwith (Standing Order No. 118(6)),',
#                 'That the draft Water Industry Act 1991 (Amendment) Order 2024, which was
# laid before this House on 15 January, be approved.—(Mark Jenkinson.)'
#             ],
#             flags=[],
#             gid='uk.org.publicwhip/debate/2024-02-07c.330.12.3'
#         ),
#         'uk.org.publicwhip/debate/2024-02-07c.330.14.2': Motion(
#             date='2024-02-07',
#             motion_title='Delegated Legislation',
#             major_heading_id='uk.org.publicwhip/debate/2024-02-07c.330.7',
#             minor_heading_id='',
#             major_heading_title='Delegated Legislation',
#             minor_heading_title='None',
#             speech_start_pid='c330.8/1',
#             speech_id='uk.org.publicwhip/debate/2024-02-07c.330.8',
#             final_speech_id='',
#             end_reason='amendment closed with name',
#             motion_lines=[
#                 'Motion made, and Question put forthwith (Standing Order No. 118(6)),',
#                 'That the draft Gender Recognition (Approved Countries and Territories and
# Saving Provision) Order 2023, which was laid before this House on 6 December 2023, be
# approved.—(Mark Jenkinson.)'
#             ],
#             flags=[],
#             gid='uk.org.publicwhip/debate/2024-02-07c.330.8.1'
#         ),
#         'uk.org.publicwhip/debate/2024-02-07c.341.0.6': Motion(
#             date='2024-02-07',
#             motion_title='Adjournment Debate: Physician Associates',
#             major_heading_id='uk.org.publicwhip/debate/2024-02-07c.331.0',
#             minor_heading_id='',
#             major_heading_title='Physician Associates',
#             minor_heading_title='None',
#             speech_start_pid='c331.1/1',
#             speech_id='uk.org.publicwhip/debate/2024-02-07c.331.1',
#             final_speech_id='',
#             end_reason='one line motion',
#             motion_lines=[
#                 'Motion made, and Question proposed, That this House do now adjourn.—(Mark
# Jenkinson.)'
#             ],
#             flags=['one_line_motion'],
#             gid='uk.org.publicwhip/debate/2024-02-07c.331.1.1'
#         )
#     }
# }

# %%
rich.print(mm.found_agreements)
# Out:
# Collection[Agreement](
#     motions=[
#         Agreement(
#             date='2024-01-26',
#             speech_id='uk.org.publicwhip/debate/2024-01-26d.526.2',
#             major_heading_id='uk.org.publicwhip/debate/2024-01-26d.505.4',
#             minor_heading_id='',
#             paragraph_pid='d526.2/5',
#             end_reason='one_line_agreement',
#             agreement_pid='',
#             agreed_text='Question put and agreed to.',
#             preceeding_text='I am glad to have been able to work cross-party with the
# Minister to ensure that we make this progress. He and I worked on a number of issues over the
# years before he gained the dizzy heights of high office. As I said in my speech, we must not
# let the perfect get in the way of the good. I will carry on championing this issue with my
# hon. Friend the Member for Harrow West, who I hope will be on the Government Benches
# following the general election, to ensure that we bring about more change. I will also carry
# on working with Conservative Members to support people in bereavement, talk about it and
# ensure that the issue is always raised as something that everyone faces across the political
# divide.',
#             after_text='Bill accordingly read a Second time; to stand committed to a Public
# Bill Committee (Standing Order No. 63).',
#             gid='uk.org.publicwhip/debate/2024-01-26d.526.2.5'
#         ),
#         Agreement(
#             date='2024-01-26',
#             speech_id='uk.org.publicwhip/debate/2024-01-26d.554.0',
#             major_heading_id='uk.org.publicwhip/debate/2024-01-26d.528.0',
#             minor_heading_id='',
#             paragraph_pid='d554.0/5',
#             end_reason='one_line_agreement',
#             agreement_pid='',
#             agreed_text='Question put and agreed to.',
#             preceeding_text='I stress that we have been working hard to get this Bill
# together. I hope that we can continue to work across the House to bring it forward and take
# it through the other place and deliver what will I think be an important piece of legislation
# to get our high streets back on track—to revive them and to bring people back into our towns
# and communities so that they can thrive once again.',
#             after_text='Bill accordingly read a Second time; to stand committed to a Public
# Bill Committee (Standing Order No. 63).',
#             gid='uk.org.publicwhip/debate/2024-01-26d.554.0.5'
#         ),
#         Agreement(
#             date='2024-01-26',
#             speech_id='uk.org.publicwhip/debate/2024-01-26d.563.1',
#             major_heading_id='uk.org.publicwhip/debate/2024-01-26d.556.0',
#             minor_heading_id='',
#             paragraph_pid='d563.1/2',
#             end_reason='one_line_agreement',
#             agreement_pid='',
#             agreed_text='Question put and agreed to.',
#             preceeding_text='What a good-natured and constructive debate we have had.',
#             after_text='Bill accordingly read a Second time; to stand committed to a Public
# Bill Committee (Standing Order No. 63).',
#             gid='uk.org.publicwhip/debate/2024-01-26d.563.1.2'
#         ),
#         Agreement(
#             date='2024-01-26',
#             speech_id='uk.org.publicwhip/debate/2024-01-26d.575.1',
#             major_heading_id='uk.org.publicwhip/debate/2024-01-26d.564.0',
#             minor_heading_id='',
#             paragraph_pid='d575.1/4',
#             end_reason='one_line_agreement',
#             agreement_pid='',
#             agreed_text='Question put and agreed to.',
#             preceeding_text='Finally, I thank Mervyn Thomas, the founder president of CSW. He
# started CSW 43 years ago and has worked on this issue ever since. He approached me within a
# few days of my entering this House as a Member of Parliament and asked whether he could
# discuss the issue with me. I pay tribute to him for all that he has done over the years. It
# is so encouraging to hear him say that there has never been a time at which those around the
# world concerned about abuses of freedom of religion or belief have been working more
# collaboratively. That is much needed, because there has never been a time when those abuses
# have been so great. This Bill and its safe passage will be an important step in strengthening
# the UK’s work, in collaboration with others, towards a future in which freedom of religion or
# belief is honoured and stronger.',
#             after_text='Bill accordingly read a Second time; to stand committed to a Public
# Bill Committee (Standing Order No. 63).',
#             gid='uk.org.publicwhip/debate/2024-01-26d.575.1.4'
#         ),
#         Agreement(
#             date='2024-01-26',
#             speech_id='uk.org.publicwhip/debate/2024-01-26d.585.0',
#             major_heading_id='uk.org.publicwhip/debate/2024-01-26d.580.0',
#             minor_heading_id='',
#             paragraph_pid='d585.0/4',
#             end_reason='one_line_agreement',
#             agreement_pid='',
#             agreed_text='Question put and agreed to.',
#             preceeding_text='Peace is not cheap. That is why we support our deterrent, whose
# existence has kept us and our allies safe for decades, and we remain fully committed to
# investing in it. Of course, we absolutely hope never to have to use our arsenal, but in our
# more dangerous world, I strongly agree with Lord Pym when he told this House, 44 years ago
# almost to the day, that irrespective of the nature of the threat we face, it is better to
# have “effective options” than accept defeat. Or, as I would put it sincerely, the best way to
# avoid a war is to deter it from happening in the first place.',
#             after_text='House adjourned.',
#             gid='uk.org.publicwhip/debate/2024-01-26d.585.0.4'
#         )
#     ]
# )
